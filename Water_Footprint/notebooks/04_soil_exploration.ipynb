# %% [markdown]
# # Soil Exploration
#
# Inspect the DSMW columns, then choose attributes from the paper's Table 1.
#
# Do not invent soil variables.

# %%
import sys, pathlib
sys.path.insert(0, str(pathlib.Path.cwd().parent))
# %load_ext autoreload
# %autoreload 2

# %%
import geopandas as gpd
from src.config import load_config
from src.soil import find_soil_source

cfg = load_config()
src = find_soil_source(cfg['paths']['raw_soil'])
gdf = gpd.read_file(src, rows=20)
list(gdf.columns)
