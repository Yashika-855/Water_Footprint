# %% [markdown]
# # Crop Calendar Exploration
#
# Planting/maturity days, season length, and the seven-day rule.
#
# Check that winter wheat (`wwh`) seasons wrap past New Year correctly.

# %%
import sys, pathlib
sys.path.insert(0, str(pathlib.Path.cwd().parent))
# %load_ext autoreload
# %autoreload 2

# %%
from src.config import load_config
from src.io_utils import load_table

cfg = load_config()
cal = load_table(cfg['paths']['interim'] / cfg['output']['calendar_table'])
cal[['planting_doy','maturity_doy','season_length_days','n_growing_months']].describe()
