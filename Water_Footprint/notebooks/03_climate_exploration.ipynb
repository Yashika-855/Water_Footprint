# %% [markdown]
# # Climate Exploration
#
# Validate ONE variable before downloading the other six.
#
# Check the NetCDF `units` attribute against `config.yaml` before trusting any conversion.

# %%
import sys, pathlib
sys.path.insert(0, str(pathlib.Path.cwd().parent))
# %load_ext autoreload
# %autoreload 2

# %%
from src.config import load_config
from src.climate import monthly_climatology

cfg = load_config()
clim = monthly_climatology(cfg, 'pr')
print(clim.attrs)
clim
