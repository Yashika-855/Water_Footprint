# %% [markdown]
# # Model Results
#
# Feature ranking, cluster diagnostics, and the final comparison table.
#
# Remember: RQ2 needs a single global model as the baseline.

# %%
import sys, pathlib
sys.path.insert(0, str(pathlib.Path.cwd().parent))
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
from src.config import load_config

cfg = load_config()
pd.read_csv(cfg['paths']['tables'] / 'model_comparison.csv')
