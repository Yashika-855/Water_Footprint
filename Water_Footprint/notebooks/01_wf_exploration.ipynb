# %% [markdown]
# # Water Footprint Exploration
#
# Inspect the ACEA wheat files, build the target, check the distributions.
#
# Run `python scripts/00_data_inventory.py` and `scripts/01_prepare_wf.py` first.

# %%
import sys, pathlib
sys.path.insert(0, str(pathlib.Path.cwd().parent))
# %load_ext autoreload
# %autoreload 2

# %%
from src.config import load_config
from src.io_utils import load_table

cfg = load_config()
wf = load_table(cfg['paths']['interim'] / cfg['output']['wf_table'])
print(wf.shape)
wf.describe()
